# %% [markdown]
# # Structures de données linéaires : Implémentation

# %% [markdown]
# ---
# ## Implémentation d'une classe `Cellule`
#
# >Voici une implémentation en POO d'une liste chaînée, la valeur de chaque cellule sera contenue dans un attribut `valeur` et l'atttribut `lien` contiendra un autre objet de type `Cellule` correspondant à la cellule suivante.

# %%
class Cellule :
    """Classe représentant une Liste chaînée"""
    def __init__(self, v, l):
        self.valeur = v
        self.lien = l

# %% [markdown]
# Instancions maintenant 3 objets et chaînons-les :

# %%
# Création d'une première cellule contenant la valeur 3 et pointant vers rien (None)
c1 = Cellule(3,None)

# Création d'une seconde cellule contenant la valeur 5 et liée à la première
c2 = Cellule(5, c1)

# Création d'une troisième cellule contenant la valeur 1 et liée à la seconde
c3 = Cellule(1, c2)

# %% [markdown]
# Le résultat obtenu est une liste composée des cellules : **$1 → 5 → 3$**
#
# La ligne de commande suivante vous permettra de créer directement une liste nommée `lst` contenant les mêmes cellules :

# %%
lst = Cellule(1, Cellule(5, Cellule(3,None)))

# %% [markdown]
# - La variable `lst` contient l'adresse mémoire de l'objet contenant la valeur $1$ qui lui même contient l'adresse de l'autre objet contenant $5$ qui lui même contient l'adresse du dernier objet contenant la valeur $3$ et l'attribut lien `None` (queue de la liste).
#
# - Il s'agit d'une définition récursive de la notion de liste, une liste est en fait ici une cellule.
#
# - Cette implémentation est cependant incomplète, car il n'est pour l'instant pas possible d'afficher une version plus lisible de cette liste puisque c'est un objet.

# %%
print(lst)

# %% [markdown]
# Les lignes de commandes suivantes permettront de retrouver les éléments **1**, **5** et **3**

# %%
# pour l'élément 1
lst.valeur

# %%
# pour l'élément 5
lst.lien.valeur

# %%
# pour l'élément 3
lst.lien.lien.valeur

# %% [markdown]
# Vous constaterez que l'interface proposée ici n'est pas des plus pratiques...
# Le code ci-dessous permettra d'afficher la cellule correctement :

# %%
# On initialise la première cellule avec lst
c = lst

# Tant que la cellule n'est pas None,
while c != None :
    # On affiche la valuer de la cellule suivi d'un espace
    print(c.valeur,end=" ")
    # c devient la cellule suivante
    c = c.lien

# %% [markdown]
# ---
# ## Implémentation d'une classe `Pile`
# > Voici en POO une classe `Pile` qui représente une pile, elle contient :
# >- Un constructeur qui ne prend aucun paramètre et initialise un attribut `data` contenant un tableau Python (type `list`) vide
# >- Une méthode `est_vide()` qui renvoie `True` si la pile est vide (si le tableau ne comporte aucun élément) et `False` sinon
# >- Une méthode `empile(v)` qui ajoute la valeur `v` passée en paramètre au sommet de la pile (soit donc à la fin du tableau)
# >- Une méthode `depile()` qui renvoie la valeur du sommet de la pile (le dernier élément du tableau) et le supprime de la pile. Si la pile est vide la methode affichera *"Pile vide"* et retournera `None`
# >- Une méthode `__repr__` qui permet d'afficher les éléments de la pile du plus ancien au plus récent (le sommet en dernier). La méthode retourne `None` et affichera *"Pile vide"* si la pile est vide.

# %% [markdown]
# ### 💻 EXERCICE 1  - Implémentation d'une pile
# >
# > - Complétez les pointillés dans le code suivant en suivant les consignes ci-dessus
# >
# > 💡 _Référez-vous aux rappels de 1ere sur les tableaux indexés pour trouver les fonctions permettant l'ajout et la suppression d'éléments dans un tableau. Vous pouvez également consulter l'aide sur le type `list` de Python [ici](https://docs.python.org/fr/3/tutorial/datastructures.html#more-on-lists)_

# %%
class Pile():
    """Classe représentant une pile"""
    
    def __init__(self):
        """Constructeur : pile vide"""
        self.data = ... # à compléter

    def est_vide(self):
        """Renvoie True si la pile est vide"""
        return ...      # à compléter
    
    def empile(self,v):
        """Empile un élément"""
        self.data. ...  # à compléter
        
    def depile(self):
        """Dépile un élément"""
        if self.est_vide():
            print("Pile vide")
            return ...  # à compléter
        else:
            return ...  # à compléter
    
    def __repr__(self):
        """Affichage"""
        chaine = ""
        if self.est_vide():
            return "Pile vide"
        else:
            for e in self.data:
                chaine = "|" + str(e) + "|\n" + chaine
            return chaine

# %%
# Vérifications
p = Pile()             # Création de la pile
p.empile(10)           # Empiler 10
p.empile(11)           # Empiler 11
p.empile(12)           # Empiler 12
p.empile(13)           # Empiler 13
v=p.depile()           # Dépiler et renvoyer le 1er élément
print(v)               # Afficher l'élément dépilé : 13
print()

print(p)               # Afficher le contenu de la pile : 10 11 12 (10 en bas 12 en haut)
print(p.est_vide())    # Vérification si la pile est vide : False
print()
for i in range(3):     # Dépiler 3 éléments
    p.depile()
print(p.est_vide())    # Vérifier si la pile est vide : True
print()
print(p.depile())      # Message "Pile vide" et retourne None
print()
print(p)               # Afficher le contenu de la pile message "Pile vide"

# %% [markdown]
# ---
# ### 💻 EXERCICE 2 : Inverser les éléments d'une pile
# > Disposant de la classe `Pile`, créez maintenant une fonction `renverse` qui prend en paramètre un objet de la classe `Pile` et renvoie un nouvel élément de la classe contenant les mêmes éléments dans l'ordre inversé
# >
# > 💡 _Utilisez une pile temporaire et une boucle `while` et dépilez la pile dans la pile temporaire_

# %%
# à compléter

# %%
##### Vérifications
p1 = Pile()             # Création de la pile
p1.empile(1)            # Empiler 1
p1.empile(2)            # Empiler 2
p1.empile(3)            # Empiler 3
p1.empile(4)            # Empiler 4
print(p1)               # Afficher le contenu de la pile
p2=renverse(p1)         # Inverser les éléments
print(p2)               # Afficher le contenu de la nouvelle pile

# %% [markdown]
# > 📌 **Vous noterez qu'à l'issue de cette fonction, la pile d'origine a été vidée :**

# %%
print(p1)

# %% [markdown]
# ---
# ### 💻 EXERCICE 3 : Copier une pile
# > Créez maintenant une fonction `copy` qui prend en paramètre un objet de la classe `Pile` et renvoie un nouvel élément de la classe contenant les mêmes éléments dans le même ordre

# %%
# à compléter

# %%
# Vérifications
p3 = Pile()             # Création de la pile
p3.empile(1)            # Empiler 1
p3.empile(2)            # Empiler 2
p3.empile(3)            # Empiler 3
p3.empile(4)            # Empiler 4
print(p3)               # Afficher le contenu de la pile
p4=copy(p3)             # Copier les éléments
print(p4)               # Afficher le contenu de la nouvelle pile
print(p3)               # Afficher le contenu de la pile d'origine

# %% [markdown]
# ---
# ### 💻 EXERCICE 4 : Séparer les éléments d'une pile
# > Créez maintenant une fonction `separe` qui prend en paramètre un objet de la classe `Pile` et renvoie un tuple de deux nouveaux éléments de la classe, l'un contenant les éléments pairs et l'autre les éléments impairs.
# >
# > ⚠️ **Attention : les éléments des deux piles renvoyées doivent être dans l'ordre initial.**
# >
# > 💡 _Utilisez la fonction `renverse`_

# %%
# à compléter

# %%
# Vérifications
p5 = Pile()             # Création de la pile
p5.empile(1)            # Empiler 1
p5.empile(2)            # Empiler 2
p5.empile(3)            # Empiler 3
p5.empile(4)            # Empiler 4
p5.empile(5)            # Empiler 5
p5.empile(6)            # Empiler 6

print(p5)               # Afficher le contenu de la pile
p6,p7=separe(p5)        # Séparer les éléments
print(p6)               # Afficher le contenu des nouvelles piles
print(p7)
print(p5)               # Afficher le contenu de la pile d'origine

# %% [markdown]
# ---
# ## Implémentation d'une classe `File`
#
# ### 💻 EXERCICE 5  - Implémentation d'une file
# >En vous inspirant de la classe `Pile` ci-dessus, créez maintenant classe `File` qui représentera une file et contiendra :
# >- Un constructeur qui ne prend aucun paramètre et initialise un attribut `data` contenant un tableau Python (type `list`) vide
# >- Une méthode `est_vide()` qui renvoie `True` si la file est vide et `False` sinon
# >- Une méthode `enfile(v)` qui ajoute la valeur `v` passée en paramètre en queue de file (au début du tableau)
# >- Une méthode `defile()` qui renvoie la valeur de tête de la file (le dernier élément du tableau) et le supprime de la file. Si la file est vide la methode affichera *"File vide"* et retournera `None`
# >- Une méthode `__repr__` qui permet d'afficher les éléments de la file tête à droite et queue à gauche sous la forme `|3|6|2|5|`). La fonction retournera `None` et affichera *"File vide"* si la file est vide

# %%
# à compléter

# %%
# Vérifications
f = File()             # Création de la file
f.enfile(10)           # Enfiler 10
f.enfile(11)           # Enfiler 11
f.enfile(12)           # Enfiler 12
f.enfile(13)           # Enfiler 13
v=f.defile()           # Défiler et renvoyer le 1er élément
print(v)               # Afficher l'élément défilé : 10
print(f)               # Afficher le contenu de la file : 13 12 11
print(f.est_vide())    # Vérification si la file est vide : False
for i in range(3):     # Défiler 3 éléments
    f.defile()         
print(f.est_vide())    # Vérifier si la file est vide : True
print(f)               # Afficher le contenu de la file message "File vide"

# %% [markdown]
# ---
# ### 💻 EXERCICE 6 : Inverser les éléments d'une file
# > Créez maintenant une fonction `renverse_f` qui prend en paramètre un objet de la classe `File` et renvoie un nouvel élément de la classe contenant les mêmes éléments dans l'ordre inversé
# >
# > *💡 Utilisez une pile temporaire et une boucle `while`*

# %%
# à compléter

# %%
# Vérifications
f1 = File()              # Création de la file
f1.enfile(1)             # Enfiler 1
f1.enfile(2)             # Enfiler 2
f1.enfile(3)             # Enfiler 3
f1.enfile(4)             # Enfiler 4
print(f1)                # Afficher le contenu de la file
f2=renverse_f(f1)        # Inverser les éléments
print(f2)                # Afficher le contenu de la nouvelle file
print(f1)                # Notez ici que la file d'origine sera vidée

# %% [markdown]
# ---
# ### 💻 EXERCICE 7 : Copier les éléments d'une file
# > Créez maintenant une fonction `copy_f` qui prend en paramètre un objet de la classe `File` et renvoie un nouvel élément de la classe contenant les mêmes éléments dans le même ordre

# %%
# à compléter

# %%
# Vérifications
f3 = File()             # Création de la file
f3.enfile(1)            # Enfiler 1
f3.enfile(2)            # Enfiler 2
f3.enfile(3)            # Enfiler 3
f3.enfile(4)            # Enfiler 4
print(f3)               # Afficher le contenu de la file
f4=copy_f(f3)           # Copier les éléments
print(f4)               # Afficher le contenu de la nouvelle file
print(f3)               # Afficher le contenu de la file d'origine

# %% [markdown]
# ---
# ### 💻 EXERCICE 8 : Séparer les éléments d'une file
# > Créez maintenant une fonction `separe_f` qui prend en paramètre un objet de la classe `File` et renvoie un tuple de deux nouveaux éléments de la classe, l'un contenant les éléments pairs et l'autre les éléments impairs.
# >
# > ⚠️ **Attention : les éléments des deux files renvoyées doivent être dans l'ordre initial.**

# %%
# à compléter

# %%
# Vérifications
f5 = File()             # Création de la file
f5.enfile(1)            # Enfiler 1
f5.enfile(2)            # Enfiler 2
f5.enfile(3)            # Enfiler 3
f5.enfile(4)            # Enfiler 4
f5.enfile(5)            # Enfiler 5
f5.enfile(6)            # Enfiler 6

print(f5)               # Afficher le contenu de la file
f6,f7=separe_f(f5)      # Séparer les éléments
print(f6)               # Afficher le contenu des nouvelles files
print(f7)

# %% [markdown]
# ---
# ## Comment éviter le vidage des objets lors du parcours de ceux-ci ?
# Comme vous l'avez remarqué lors des exercices précédents, le parcours d'une pile ou d'une file vide celle-ci.
# Pour éviter cela, il faut passer par un objet temporaire et à chaque dépilage (ou défilage) remettre l'élément dans
# l'objet temporaire pour ne pas le perdre. A la fin, il faut remettre les éléments de l'objet temporaire dans l'objet initial.
#
# Les deux exercices suivants permettent de calculer la taille d'une Pile puis d'une File en laissant l'objet d'origine inchangé :

# %% [markdown]
# ---
# ### 💻 EXERCICE 9 : Compter les éléments d'une File
# > Complétez la fonction ci dessous à partir des indications en commentaire

# %%
def taille_f(f):
    nb = ...        # Initialiser le compteur à 0
    ftemp = ...  # Créer une file temporaire
    while not f.est_vide():
        ftemp.enfile(...)   #  défiler un élément de f et l'enfiler dans ftemp 
        nb  = ... # Incrémenter le compteur
    
    # Remise de la file f à son état initial en parcourant ftemp
    while not ... .est_vide():
        ...   #  défiler un élément de ftemp et l'enfiler dans f     
    
    return nb   # Renvoyer le nombre d'éléments

# %%
# Vérifications
f8 = File()             # Création de la pile
f8.enfile(1)            # Enfiler 1
f8.enfile(2)            # Enfiler 2
f8.enfile(3)            # Enfiler 3
f8.enfile(4)            # Enfiler 4

print(f8)               # Afficher le contenu de la file

n = taille_f(f8)         # Compter les éléments
print(n)                # Afficher le nb d'éléments : 4

print(f8)               # Afficher le contenu de la file d'origine

# %% [markdown]
# ---
# ### 💻 EXERCICE 10 : Compter les éléments d'une Pile
# > En vous inspirant de la fonction ci-dessus, écrivez une fonction `taille_f(f)` qui renverra le nombre d'éléments dans une pile en laissant le contenu de celle-ci inchangé.

# %%
# à compléter

# %%
# Vérifications
p8 = Pile()             # Création de la pile
p8.empile(1)            # Empiler 1
p8.empile(2)            # Empiler 2
p8.empile(3)            # Empiler 3
p8.empile(4)            # Empiler 4

print(p8)               # Afficher le contenu de la pile

n = taille_p(p8)         # Compter les éléments
print(n)                # Afficher le nb d'éléments : 4
print()

print(p8)               # Afficher le contenu de la file d'origine
