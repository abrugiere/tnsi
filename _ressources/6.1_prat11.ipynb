# %% [markdown]
# # Épreuve pratique niveau première - Facile
# >**Les sujets sélectionnés ici demandent des connaissances de niveau 1ère. Ils sont en général proposés en exercice 1 de chaque sujet qui consiste à programmer un algorithme figurant explicitement au programme, ne présentant pas de difficulté particulière, dont on fournit une spécification.**
# >
# >⚠️ _**Dans ce type de sujet, l'utilisation des fonctions et méthodes natives comme `max`, `min`, `sorted`, `mean`, `sort`, `sum`… sont interdites.**_

# %% [markdown]
# ---
# ### 💻 Exercice 1 : Somme
#
# Écrire la fonction `somme_tableau` prenant en paramètre un tableau non vide d'entiers `tab` (de type _list_) et renvoyant la somme des éléments de ce tableau.
#
# _Exemples_ :
# ``` Python
# >>> somme_tableau([5, 12, 4, 23, 14, 2])
# 60
# >>> somme_tableau([-10, 12, -3, 1])
# 0
# ```

# %%
#💡 Initialisez une variable 's' à 0 puis parcourez chaque valeur du tableau et ajoutez-la a 's'

# %%
somme_tableau([5, 12, 4, 23, 14, 2])

# %%
somme_tableau([-10, 12, -3, 1])

# %% [markdown]
# ---
# ### 💻 Exercice 2 : Maximum
#
# Écrire la fonction `maximum_tableau` prenant en paramètre un tableau non vide d'entiers `tab` (de type _list_) et renvoyant le plus grand élément de ce tableau.
#
# _Exemples_ :
# ``` Python
# >>> maximum_tableau([98, 12, 104, 23, 131, 9])
# 131
# >>> maximum_tableau([-27, 24, -3, 15])
# 24
# ```

# %%
#💡 Initialisez une variable 'maxi' contenant la premiere valeur du tableau 
#   puis parcourez chaque valeur du tableau et remplacez 'maxi' par la valeur si celle-ci est > à maxi

# %%
maximum_tableau([98, 12, 104, 23, 131, 9])

# %%
maximum_tableau([-27, 24, -3, 15])

# %% [markdown]
# ---
# ### 💻 Exercice 3 : Maximum et indice
# Écrire une fonction `max_et_indice` qui prend en paramètre un tableau non vide `tab`
# (type Python _list_) de nombres entiers et qui renvoie la valeur du plus grand élément de ce tableau ainsi que l’indice de sa première apparition dans ce tableau.
#
# _Exemples_ :
# ``` Python
# >>> max_et_indice([1, 5, 6, 9, 1, 2, 3, 7, 9, 8])
# (9, 3)
# >>> max_et_indice([-2])
# (-2, 0)
# >>> max_et_indice([-1, -1, 3, 3, 3])
# (3, 2)
# >>> max_et_indice([1, 1, 1, 1])
# (1, 0)
# ```

# %%
#💡 Idem mais ici il va falloir également mémoriser l'indice de la valeur maxi dans une variable

# %%
max_et_indice([1, 5, 6, 9, 1, 2, 3, 7, 9, 8])

# %%
max_et_indice([-2])

# %%
max_et_indice([-1, -1, 3, 3, 3])

# %%
max_et_indice([1, 1, 1, 1])

# %% [markdown]
# ---
# ### 💻 Exercice 4 : Indice du minimum
# Écrire une fonction `recherche_min` qui prend en paramètre un tableau de nombres `tab`, et qui renvoie l’indice de la première occurrence du minimum de ce tableau. Les tableaux seront représentés sous forme de liste Python.
#
# _Exemples_ :
# ``` Python
# >>> recherche_min([5])
# 0
# >>> recherche_min([2, 4, 1])
# 2
# >>> recherche_min([5, 3, 2, 2, 4])
# 2
# >>> recherche_min([-1, -2, -3, -3])
# 2
# ```

# %%
#💡 Idem

# %%
recherche_min([5])

# %%
recherche_min([2, 4, 1])

# %%
recherche_min([5, 3, 2, 2, 4])

# %%
recherche_min([-1, -2, -3, -3])

# %% [markdown]
# ---
# ### 💻 Exercice 5 : Minimum et maximum
# Écrire une fonction `min_et_max` qui prend en paramètre un tableau de nombres `tab` non vide, et qui renvoie la plus petite et la plus grande valeur du tableau sous la forme d’un dictionnaire à deux clés `min` et `max`.
# Les tableaux seront représentés sous forme de liste Python.
#
# _Exemples_ :
# ``` Python
# >>> min_et_max([0, 1, 4, 2, -2, 9, 3, 1, 7, 1])
# {'min': -2, 'max': 9}
# >>> min_et_max([0, 1, 2, 3])
# {'min': 0, 'max': 3}
# >>> min_et_max([3])
# {'min': 3, 'max': 3}
# >>> min_et_max([1, 3, 2, 1, 3])
# {'min': 1, 'max': 3}
# >>> min_et_max([-1, -1, -1, -1, -1])
# {'min': -1, 'max': -1}
# ```

# %%
#💡 Idem

# %%
min_et_max([0, 1, 4, 2, -2, 9, 3, 1, 7, 1])

# %%
min_et_max([0, 1, 2, 3])

# %%
min_et_max([3])

# %%
min_et_max([1, 3, 2, 1, 3])

# %%
min_et_max([-1, -1, -1, -1, -1])

# %% [markdown]
# ---
# ### 💻 Exercice 6 : Température minimale
# On a relevé les valeurs moyennes annuelles des températures à Paris pour la période allant de 2013 à 2019. Les résultats ont été récupérés sous la forme de deux tableaux (de type _list_) : l’un pour les températures, l’autre pour les années :
# ``` Python
# t_moy = [14.9, 13.3, 13.1, 12.5, 13.0, 13.6, 13.7]
# annees = [2013, 2014, 2015, 2016, 2017, 2018, 2019]
# ```
# Écrire la fonction `annee_temperature_minimale` qui prend en paramètres ces deux tableaux et qui renvoie la plus petite valeur relevée au cours de la période et l’année correspondante. On suppose que la température minimale n'est atteinte qu'une seule fois.
#
# _Exemple_ :
# ``` Python
# >>> annee_temperature_minimale(t_moy, annees)
# (12.5, 2016)
# ```

# %%
#💡 Trouvez le minimum de la première liste et son indice puis renvoyez les éléments des deux tableaux à l'indice trouvé

# %%
t_moy = [14.9, 13.3, 13.1, 12.5, 13.0, 13.6, 13.7]
annees = [2013, 2014, 2015, 2016, 2017, 2018, 2019]

# %%
annee_temperature_minimale(t_moy, annees)

# %% [markdown]
# ---
# ### 💻 Exercice 7 : Recherche de la première occurence
# Écrire une fonction `recherche` qui prend en paramètres `elt` un nombre entier et `tab` un tableau de nombres entiers (type _list_), et qui renvoie l’indice de la **première** occurrence de `elt` dans `tab` si `elt` est dans `tab` et `None` sinon.
# L’objectif de cet exercice est de parcourir un tableau, il est interdit d’utiliser la méthode `index` des listes Python.
#
# _Exemples_ :
# ``` Python
# >>> recherche(1, [2, 3, 4]) # renvoie None
# >>> recherche(1, [10, 12, 1, 56])
# 2
# >>> recherche(1, [1, 50, 1])
# 0
# >>> recherche(15, [8, 9, 10, 15])
# 3
# ```

# %%
#💡 Parcourez le tableau par les indices et comparez chaque élément à elt, renvoyez l'indice dès que elt est trouvé

# %%
recherche(1, [2, 3, 4])

# %%
recherche(1, [10, 12, 1, 56])

# %%
recherche(1, [1, 50, 1])

# %%
recherche(15, [8, 9, 10, 15])

# %% [markdown]
# ---
# ### 💻 Exercice 8 : Recherche de la dernière occurence
# Programmer la fonction `recherche` prenant en paramètres un tableau non vide `tab` (type _list_) d’entiers et un entier `n` et qui renvoie l’indice de la **dernière** occurrence de l’élément cherché. Si l’élément n’est pas présent, la fonction renvoie `None`.
#
# _Exemples_ :
# ``` Python
# >>> recherche([5, 3],1) # renvoie None
# >>> recherche([2,4],2)
# 0
# >>> recherche([2,3,5,2,4],2)
# 3
# ```

# %%
#💡 Cette fois, il faut renvoyer le dernier indice trouvé, donc il faut parcourir tout le tableau avant de renvoyer l'indice

# %%
recherche([5, 3],1)

# %%
recherche([2,4],2)

# %%
recherche([2,3,5,2,4],2)

# %% [markdown]
# ---
# ### 💻 Exercice 9 : Répétitions
# Écrire une fonction Python appelée `nb_repetitions` qui prend en paramètres un élément `elt` et un tableau `tab` (type _list_) d’éléments du même type et qui renvoie le nombre de fois où l’élément apparaît dans le tableau.
#
# _Exemples_ :
# ``` Python
# >>> nb_repetitions(5, [2, 5, 3, 5, 6, 9, 5])
# 3
# >>> nb_repetitions('A', ['B', 'A', 'B', 'A', 'R'])
# 2
# >>> nb_repetitions(12, [1, 3, 7, 21, 36, 44])
# 0
# ```

# %%
#💡 Comme pour la recherche précédente, il faut parcourir tout le tableau et incrémenter un compteur à chaque rencontre de elt

# %%
nb_repetitions(5, [2, 5, 3, 5, 6, 9, 5])

# %%
nb_repetitions('A', ['B', 'A', 'B', 'A', 'R'])

# %%
nb_repetitions(12, [1, 3, 7, 21, 36, 44])
