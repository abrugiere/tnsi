# %% [markdown]
# # Sécurisation des communications - TP

# %% [markdown]
# ---
# ### 💻 EXERCICE 1
# > En Python, la fonction `ord` permet de retourner le code _unicode_ (un nombre décimal de 65 à 90) correspondant à une lettre de l'alphabet :

# %%
ord('A')
# Out:
# 65

# %%
ord('Z')
# Out:
# 90

# %% [markdown]
# > La fonction `chr` quand à elle, renvoie la lettre de l'alphabet correspondant au code _unicode_ :

# %%
chr(65)
# Out:
# 'A'

# %%
chr(72)
# Out:
# 'H'

# %% [markdown]
# > - Ecrivez ci-dessous une fonction `cesar(decalage,phrase)` qui renvoie la chaîne `phrase` passée en paramètre décalée à l'aide du code de César décalée de `decalage`
# > 💡 Vous allez parcourir la chaine de caractères lettre par lettre, ensuite vous trouverez le code unicode de chaque lettre (avec `ord`) et lui ajouterez le décalage. Ensuite il vous suffit de retraduire le nouveau code en caractère (avec `chr`).
# > **ATTENTION** : si vous décalez de 5 la lettre Z vous allez obtenir le code 95 soit le caractère "\_", il va donc falloir retrancher 26 à votre code si celui-ci dépasse 90. Vous prendrez également en compte le fait de ne pas remplacer le caracère si c'est un espace.

# %%
# à compléter
def cesar(d,p):
    res=''
    for l in p :
        if l == ' ' :
            res = res + l
        else:
            new=ord(l)+d
            if new >90:
                new-=26
            res = res + chr(new)
    return res

# %%
# Vérification : doit renvoyer 'DQDM TI VAQ'
cesar(8,'VIVE LA NSI')

# %% [markdown]
# > - Ecrivez maintenant une fonction `rasec(decalage,phrase)` qui renvoie la chaîne `phrase` passée en paramètre décodée à l'aide du code de César

# %%
# à compléter
def rasec(d,p):
    res=''
    for l in p :
        if l == ' ' :
            res = res + l
        else:
            new=ord(l)-d
            if new <65:
                new+=26
            res = res + chr(new)
    return res

# %%
# Vérification
rasec(17,'SIRMF MFLJ RMVQ UVTYZWWIV CV TFUV')

# %% [markdown]
# ---
# ### 💻 EXERCICE 2
# > - Ecrivez ci-dessous une fonction `subs(phrase)` qui renvoie la phrase `phrase` passée en paramètre chiffrée par substitution à l'aide du dictionnaire ci-dessus.
# > 💡 En utilisant un dictionnaire, l'implémentation devient très simple

# %%
# à compléter
def subs(p):
    res=''
    dic={
        "A":"Z",
        "B":"Y",
        "C":"X",
        "D":"W",
        "E":"V",
        "F":"U",
        "G":"T",
        "H":"S",
        "I":"R",
        "J":"Q",
        "K":"P",
        "L":"O",
        "M":"N",
        "N":"M",
        "O":"L",
        "P":"K",
        "Q":"J",
        "R":"I",
        "S":"H",
        "T":"G",
        "U":"F",
        "V":"E",
        "W":"D",
        "X":"C",
        "Y":"B",
        "Z":"A",
        " ":" "
    }
    
    for l in p :
        res = res + dic[l]
    return res

# %%
# Vérification : doit renvoyer 'EREV OZ MHR'
subs('VIVE LA NSI')
