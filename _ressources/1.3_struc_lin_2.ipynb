# %% [markdown]
# # TP : Structures de données linéaires

# %% [markdown]
# ---
# ### 💻 EXERCICE 1 : Créer une classe `Pile`
# > Créez en POO la classe `Pile` qui représentera une pile, elle contiendra :
# >- Un constructeur qui ne prend aucun paramètre et initialise un attribut `data` contenant un tableau Python (type `list`) vide
# >- Une méthode `est_vide()` qui renvoie `True` si la pile est vide et `False` sinon
# >- Une méthode `empile(v)` qui ajoute la valeur `v` passée en paramètre au sommet de la pile
# >- Une méthode `depile()` qui renvoie la valeur du sommmet de la pile et le supprime de la pile. Si la pile est vide la methode affichera *"Pile vide"* et retournera `None`
# >- Une méthode `__repr__` qui permet d'afficher les éléments de la pile du plus ancien au plus récent (le sommet en dernier). La méthode retournera *"Pile vide"* si la pile est vide
# >
# > 💡 _Parcourez les éléments de la pile puis insérez dans une chaine de caractères le caractère `|` puis l'élément puis le caractère `|` et enfin un saut de lilgne (`\n`)_
# >
# > ⚠️ **L'ordre des éléments doit être respecté : le dernier élément empilé en haut et ainsi de suite**

# %%
# à compléter

# %%
# Vérifications
p = Pile()             # Création de la pile
p.empile(10)           # Empiler 10
p.empile(11)           # Empiler 11
p.empile(12)           # Empiler 12
p.empile(13)           # Empiler 13
v=p.depile()           # Dépiler et renvoyer le 1er élément
print(v)               # Afficher l'élément dépilé : 13
print(p)               # Afficher le contenu de la pile : 10 11 12 (10 en bas 12 en haut)
print(p.est_vide())    # Vérification si la pile est vide : False
for i in range(3):     # Dépiler 3 éléments
    p.depile()
print(p.est_vide())    # Vérifier si la pile est vide : True
print(p.depile())      # Message "Pile vide" et retourne None
print(p)               # Afficher le contenu de la pile message "Pile vide"

# %% [markdown]
# ### 💻 EXERCICE 2  - Utilisation d'une pile
# >En considérant que la classe `Pile` définie ci-dessus et ses méthodes existent, simulez une gestion de l'historique de navigation internet, en créant une classe `Nav` qui utilisera une pile et qui disposera des méthodes suivantes :
# > - `visite` qui prend une URL en paramètre, l'empile dans l'historique et affiche "Page actuelle : " et l'URL saisi
# > - `back` qui ne prend pas de paramètre, dépile la dernière page de historique et affiche "Page quittée : " et l'URL dépilée
# >
# >*Exemple d'utilisation :*
# > ``` Python
# > >>> n = Nav()
# > >>> n.visite('www.lemonde.fr')
# > page actuelle : www.lemonde.fr
# > >>> n.visite('www.google.fr')
# > page actuelle : www.google.fr
# > >>> n.visite('www.lyceebrugiere.fr')
# > page actuelle : www.lyceebrugiere.fr
# > >>> n.back()
# > page quittée : www.lyceebrugiere.fr
# > >>> n.back()
# > page quittée : www.google.fr
# > ```

# %%
# à compléter

# %%
# vérifications
n = Nav()
n.visite('www.lemonde.fr')
n.visite('www.google.fr')
n.visite('www.lyceebrugiere.fr')
n.back()
n.back()

# %% [markdown]
# ---
# ### 💻 EXERCICE 3 : Inverser les éléments d'une pile
# > Disposant de la classe `Pile`, créez maintenant une fonction `renverse` qui prend en paramètre un objet de la classe `Pile` et renvoie un nouvel élément de la classe contenant les mêmes éléments dans l'ordre inversé
# >
# > 💡 _Utilisez une pile temporaire et une boucle `while` et dépilez la pile dans la pile temporaire_

# %%
# à compléter

# %%
# Vérifications
p1 = Pile()             # Création de la pile
p1.empile(1)            # Empiler 1
p1.empile(2)            # Empiler 2
p1.empile(3)            # Empiler 3
p1.empile(4)            # Empiler 4
print(p1)               # Afficher le contenu de la pile
p2=renverse(p1)         # Inverser les éléments
print(p2)               # Afficher le contenu de la nouvelle pile

# %% [markdown]
# > 📌**Vous noterez qu'à l'issue de cette fonction, la pile d'origine a été vidée :**

# %%
print(p1)

# %% [markdown]
# ---
# ### 💻 EXERCICE 4 : Copier une pile
# > Créez maintenant une fonction `copy` qui prend en paramètre un objet de la classe `Pile` et renvoie un nouvel élément de la classe contenant les mêmes éléments dans le même ordre

# %%
# à compléter

# %%
# Vérifications
p3 = Pile()             # Création de la pile
p3.empile(1)            # Empiler 1
p3.empile(2)            # Empiler 2
p3.empile(3)            # Empiler 3
p3.empile(4)            # Empiler 4
print(p3)               # Afficher le contenu de la pile
p4=copy(p3)             # Copier les éléments
print(p4)               # Afficher le contenu de la nouvelle pile
print(p3)               # Afficher le contenu de la pile d'origine

# %% [markdown]
# ---
# ### 💻 EXERCICE 5 : Séparer les éléments d'une pile
# > Créez maintenant une fonction `separe` qui prend en paramètre un objet de la classe `Pile` et renvoie un couple de deux nouveaux éléments de la classe, l'un contenant les éléments pairs et l'autre les éléments impairs.
# >
# > ⚠️ **Attention : les éléments des deux piles renvoyées doivent être dans l'ordre initial.**
# >
# > 💡 _Utilisez la fonction `renverse`_

# %%
# à compléter

# %%
# Vérifications
p5 = Pile()            # Création de la pile
p5.empile(1)            # Empiler 1
p5.empile(2)            # Empiler 2
p5.empile(3)            # Empiler 3
p5.empile(4)            # Empiler 4
p5.empile(5)            # Empiler 5
p5.empile(6)            # Empiler 6

print(p5)               # Afficher le contenu de la pile
p6,p7=separe(p5)        # Séparer les éléments
print(p6)               # Afficher le contenu des nouvelles piles
print(p7)

# %% [markdown]
# ---
# ### 💻 EXERCICE 6 : Vérification du parenthésage
# > On dispose d'une chaîne de caractères contenant des parenthèses ouvrantes ou fermantes comme `(()())((())())`. Un parenthésage est considéré correct si en parcourant la chaîne de gauche à droite, à tout moment le nombre de parenthèses ouvertes est supérieur ou égale au nombre de parenthèses déjà fermées. Enfin dans la chaîne complète, il doit y avoir autant de parenthèses ouvrantes que de femantes.
# > - Ecrivez une fonction `test(c)` qui, en utilisant la classe `Pile`, parcourt la chaîne passée en paramètre et empile dans une file une valeur (`"("`) lorsque le caractère est "(" et dépile une valeur lorsque le caractère est ")". La fonction affichera le contenu de la pile à la fin de son exécution.

# %%
# à compléter

# %% [markdown]
# > - Vérifions le comportement de ce code, pour chacun des tests, expliquez le comportement de la fonction

# %%
# Vérification
test("(()())")

# %% [raw]
# Comportement : La chaîne est parcourue et la pile est remplie puis vidée, pas d'erreur.

# %%
# Vérification
test("())()(")

# %% [raw]
# Comportement : Le programme s'arrête au 3e élément car on dépile une pile vide, la chaîne n'est pas totalement parcourue

# %%
# Vérification
test("(()")

# %% [raw]
# Comportement : La chaîne est parcourue, le programme se termine mais la pile n'est pas vide à la fin

# %% [markdown]
# > - Ecrivez maintenant une fonction `parenthesage` qui prendra en paramètre une chaîne de caractères et renverra `True` si la chaîne est bien parenthésée et `False` sinon (pas de plantage).

# %%
# à compléter

# %%
# Vérifications
print(parenthesage("(()())"))   # Doit renvoyer True
print(parenthesage("())()("))   # Doit renvoyer False
print(parenthesage("(()"))      # Doit renvoyer False
print(parenthesage("(a+b)^2=a^2+2ab+b^2"))   # Doit renvoyer True
print(parenthesage("((1+1)*(3-4)^2"))        # Doit renvoyer False

# %% [markdown]
# ---
# ### 💻 EXERCICE 7 : Créer une classe `File`
# >Créez la classe `File` qui représentera une file et contiendra :
# >- Un constructeur qui ne prend aucun paramètre et initialise un attribut `data` contenant un tableau Python (type `list`) vide
# >- Une méthode `est_vide()` qui renvoie `True` si la file est vide et `False` sinon
# >- Une méthode `enfile(v)` qui ajoute la valeur `v` passée en paramètre en queue de file
# >- Une méthode `defile()` qui renvoie la valeur de tête de la file et le supprime de la file. Si la file est vide la methode affichera *"File vide"* et retournera `None`
# >- Une méthode `__repr__` qui permet d'afficher les éléments de la file du plus ancien au plus récent sous la forme `|3|6|2|5|`). La fonction retournera *"File vide"* si la file est vide
# >
# > 💡 _Le type `list` de Python peut être utilisé, Pensez à aller voir [ici](https://docs.python.org/fr/3/tutorial/datastructures.html#more-on-lists) les méthodes des objets de types `list`, notamment la méthode `insert`._

# %%
# à compléter

# %%
# Vérifications
f = File()             # Création de la file
f.enfile(10)           # Enfiler 10
f.enfile(11)           # Enfiler 11
f.enfile(12)           # Enfiler 12
f.enfile(13)           # Enfiler 13
v=f.defile()           # Défiler et renvoyer le 1er élément
print(v)               # Afficher l'élément défilé : 10
print(f)               # Afficher le contenu de la file : 13 12 11
print(f.est_vide())    # Vérification si la file est vide : False
for i in range(3):     # Défiler 3 éléments
    f.defile()         
print(f.est_vide())    # Vérifier si la file est vide : True
print(f)      # Afficher le contenu de la file message "File vide"

# %% [markdown]
# ---
# ### 💻 EXERCICE 8 : Inverser les éléments d'une file
# > Créez maintenant une fonction `renverse_f` qui prend en paramètre un objet de la classe `File` et renvoie un nouvel élément de la classe contenant les mêmes éléments dans l'ordre inversé
# >
# > *💡 Utilisez une pile temporaire et une boucle `while`*

# %%
# à compléter

# %%
# Vérifications
f1 = File()              # Création de la file
f1.enfile(1)             # Enfiler 1
f1.enfile(2)             # Enfiler 2
f1.enfile(3)             # Enfiler 3
f1.enfile(4)             # Enfiler 4
print(f1)                # Afficher le contenu de la file
f2=renverse_f(f1)        # Inverser les éléments
print(f2)                # Afficher le contenu de la nouvelle file
print(f1)                # Notez ici que la file d'origine sera vidée

# %% [markdown]
# ---
# ### 💻 EXERCICE 9 : Distribution d'un jeu de cartes
# > Nous souhaitons simuler la distribution d'un jeu de 32 cartes entre 2 joueurs.
# > Le jeu de 32 cartes sera modélisé par une pile contenant les cartes mélangées.
# > Pour la distribution, chaque carte au sommet de la pile est donné tour à tour aux deux joueurs pour constituer deux nouvelles piles. Les deux dernières cartes distribuées sont donc au sommet de chacune des deux piles.
# > Enfin nous simulerons le déroulement d'une partie de bataille : chaque joueur découvre la carte au dessus de son tas.
# > *Note : nous n'écrirons pas le code permettant de tester qui remporte la partie, mais seulement l'affichage des paires de cartes en duel.*
# >
# > - Executez le code suivant pour générer un tableau contenant toutes les cartes du jeu mélangées :

# %%
# Code à exécuter
import random as r

# Création et affichage du jeu de cartes
cartes=[i+j for i in ['7','8','9','10','V','D','R','A'] for j in ["♠","♥","♦","♣"]]
print(cartes)

# Mélange et affichage du jeu
r.shuffle(cartes)
print(cartes)

# %% [markdown]
# > **Création du jeu de cartes**
# > - Créez maintenant un objet de la classe `Pile` nommé `jeu` et ajoutez-y les éléments du tableau `cartes` créé ci-dessus.

# %%
# à compléter

# %%
# Vérification
print(jeu)

# %% [markdown]
# > **Distribution des cartes à deux joueurs**
# > Créez maintenant une fonction `distribue` qui prendra en paramètre une pile (comme notre variable `jeu` ci-dessus) et la distribuera en deux tas, pour cela :
# > - Créez deux objets de la classe `Pile` nommés `tas1` et `tas2`.
# > - Dépilez les cartes de la pile passée en paramètre une à une puis empilez les tour à tour sur les piles `tas1` et `tas2`
# > - La fonction devra renvoyer un tuple contenant les deux tas

# %%
# à compléter

# %%
# Vérification
m1,m2=distribue(jeu)

print(m1)
print(m2)

# %% [markdown]
# > **Déroulement de la bataille**
# > - Ajoutez maintenant une ligne de code qui simulera la découverte des deux cartes du sommet de la pile de chacun des joueurs.
# > - Exemple d'affichage attendu :
# > ```Python
# > A♥  vs  9♠
# > A♣  vs  D♥
# > ...
# > Fin de partie
# ```

# %%
# à compléter

# %% [markdown]
# ---
# ### 💻 EXERCICE 9 : La notation polonaise inversée
#
# > Dans certaines calculatrices, les expressions sont évaluées à l'aide de la [notation polonaise inversée](https://fr.wikipedia.org/wiki/Notation_polonaise_inverse).
# > Cette notation ne nécessite aucune parenthèse ni aucune règle de priorité. Elle place les opérandes avant les opérateurs.
# >
# > **Exemple**
# >
# > En notation polonaise inversée, l'expression `(1+2)*3+4` peut s'écrire `4321+*+`.
# >
# >* Pour calculer cette expression, on lit de gauche à droite jusqu'à trouver un opérateur, ici $+$.
# >* On utilise ensuite les deux derniers opérandes trouvés qui sont $2$  et $1$, puis on effectue l'opération $1+2$.
# >* On remplace les opérandes et l'opérateur utilisés par le résultat de l'opération, ici l'expression devient alors `433*+`.
# >* On utilise l'opérateur suivant sur les deux derniers opérandes présents dans l'expression.Ici on effectue donc $3 \times 3$.
# >* On remplace les opérandes et l'opérateur utilisés par le résultat de l'opération, ici l'expression devient alors `49+`.
# >* On réitère le procédé sur les derniers opérandes, ce qui revient ici à effectuer le calcul $4+9$.
# >* Le résultat est bien $13$ qui est aussi le résutat de $(1+2)*3+4$.
# >
# > **Manipulation**
# > 1. Quelle notation sera utilisée pour calculer `(3+4)*6+1` ?
# > __Réponse :__ `1634+*+`
# > 2. A quelle expression correspond la notation `4132*+*`?
# > __Réponse :__ `((2*3)+1)*4`
# >
# > **Implémentation**
# >
# >Pour simplifier , on suppose que :
# >- L'on utilise uniquement les opérateurs `+` et `*`.
# >- Les opérandes sont des entiers naturels à un chiffre (entre 0 et 9).
# >- L'expression à évaluer est une chaîne de caractères.
# >
# >La valeur d'une expression en notation polonaise inversée peut être calculée à l'aide d'une pile pour stocker les résultats intermédiaires. Pour cela, on parcourt l'expression de gauche à droite et on effectue les actions suivantes :
# >- Si on voit un nombre , on le place sur la pile.
# >- Si on voit un opérateur, on récupère les deux nombres au sommet de la pile, on leur applique l'opérateur et on replace le résultat au sommet de la pile.
# >- A la fin du processus, il reste exactement un nombre sur la pile, qui est le résultat.
# >
# >Ecrire la fonction `npi(expr)` qui prend en paramètre un chaîne de caractères contenant une expression à évaluer et qui renvoie le résultat de l'évalution de cette expression.
# >
# > 💡 _Pour tester si un élément de cette liste de caractères est un nombre, on utilisera la méthode `isdigit()` sur les caractères. Cette méthode renvoie `True` si l'élément est un chiffre et `False` sinon._

# %%
# à compléter

# %%
# Vérification
exp1='4312+*+'
exp2='1643+*+'
exp3='4132*+*'

print(npi(exp1)) # Doit renvoyer 13
print(npi(exp2)) # Doit renvoyer 43
print(npi(exp3)) # Doit renvoyer 28
