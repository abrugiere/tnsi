# %% [markdown]
# # Algorithmes sur les arbres binaires et parcours
# ![parcours_arbres.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ---
# ## Introduction
#
# Dans ce cours, nous utiliserons l'implémentation en **P**rogrammation **O**rientée **O**bjet, en version **sans encapsulation**. Nous allons créer des fonctions calculant sa taille, sa hauteur, son nombre de feuilles ou encore renvoyant les différents parcours d'un arbre... Toutes ses fonctions exploiteront la structure récursive d'un arbre.
#
# >⚠️ Par soucis de clarté, nous conviendrons par la suite d'appeler _**SAG**_ le sous-arbre gauche et et _**SAD**_ le sous-arbre droit d'un arbre.
#
# ### Rappel de l'implémentation
#
# La représentation utilisée dans le cours précédent sera reprise avec la fonction `__repr__` que nous avons développé dans le dernier exercice.

# %%
# à exécuter
class Arbre:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

    def __repr__(self):
        chaine= "(" + str(self.data) + ", "
        if self.left == None:
            chaine = chaine + "∆, "
        else:
            chaine = chaine + self.left.__repr__() + ', '
        if self.right == None:
            chaine = chaine + "∆)"
        else:
            chaine = chaine + self.right.__repr__() + ")"

        return chaine

# %% [markdown]
# ---
# ### 💻 EXERCICE 1 - Création de notre arbre
# Nous allons implémenter tous les différents algorithmes en utilisant le même exemple, considérons l'arbre suivant :
#
# ![algo.jpg](data:image/jpeg;base64,...)
#
# > - Créez un instance `arb` de cet arbre en utilisant la classe `Arbre` fournie ci-dessus

# %%
# à completer

# %% [markdown]
# > - Affichez la représentation en console de cet arbre, de son sous-arbre gauche et de son sous-arbre droit.

# %%
# à completer

# %% [markdown]
# ---
# ### 💻 EXERCICE 2 - Taille d'un arbre binaire
#
# La taille d'un arbre est le nombre de ses nœuds, pour calculer la taille d'un arbre, nous allons utiliser la structure récursive de l'arbre.
# La taille d'un arbre vide est 0.
#
# $$taille(arbre) = \left\{ \begin {array} {ll} {~si~arbre~est~vide}~~renvoyer~0 \\ {sinon}~~renvoyer~1~+~taille(SAG)~+~taille(SAD) \end{array}\right.$$
#
#
#
# > - Quelle est la taille de notre arbre ?

# %% [markdown]
# > - En utilisant la définition récursive de la taille d'un arbre, implémentez la fonction `taille`.

# %%
# à compléter

# %%
# Vérification
taille(arb)

# %% [markdown]
# ---
# ### 💻 EXERCICE 3 - Hauteur d'un arbre binaire
#
# Ici, nous allons encore utiliser la structure récursive de l'arbre : la hauteur d'un arbre est 1 + la hauteur du plus haut de ses deux sous-arbres.
# Nous prendrons comme convention qu'un arbre vide a pour hauteur 0.
#
# $$hauteur(arbre) = \left\{ \begin {array} {ll} {~si~arbre~est~vide}~~renvoyer~0 \\ {sinon}~~renvoyer~1~+~max (~hauteur(SAG)~,~hauteur(SAD)~) \end{array}\right.$$
#
#
# > - Quelle est la hauteur de notre arbre ?

# %% [markdown]
# > - En utilisant la définition récursive, implémentez la fonction `hauteur`.

# %%
# à completer

# %%
# Vérification
hauteur(arb)

# %% [markdown]
# ---
# ### 💻 EXERCICE 4 - Nombre de feuilles d'un arbre binaire
#
# Pour rappel, une feuille est un noeud d'arité 0, c'est à dire sans fils gauche ni fils droit.
#
# $$nbfeuilles(arbre) = \left\{ \begin {array} {ll} {~si~arbre~est~vide}~~renvoyer~0 \\ {~si~SAG~est~vide~et~SAD~est~vide}~~renvoyer~1 \\{sinon}~~renvoyer~nbfeuilles(SAG)~+~nbfeuilles(SAD)~) \end{array}\right.$$
#
#
# > - Calculez le nombre de feuilles de notre arbre

# %% [markdown]
# > - En utilisant la définition récursive, implémentez la fonction `nbfeuilles`.

# %%
# à completer

# %%
# Vérification
nbfeuilles(arb)

# %% [markdown]
# ---
# ### 💻 EXERCICE 5 - Parcours préfixe d'un arbre binaire
#
# Dans un parcours préfixe, un noeud est visité avant le parcours préfixe de son _SAG_ et celui de son _SAD_.
# - Le parcours préfixe d'une arbre vide renverra `""`
# - Sinon il renverra l'étiquette de l'arbre puis le parcours préfixe de son _SAG_ puis le parcours préfixe de son _SAD_.
#
#
# > - Affichez le parcours préfixe de notre arbre

# %% [markdown]
# > - En utilisant la définition récursive, implémentez la fonction `prefixe`.

# %%
# à completer

# %%
# Vérification
print(prefixe(arb))

# %% [markdown]
# ---
# ### 💻 EXERCICE 6 - Parcours infixe d'un arbre binaire
#
# Dans un parcours infixe, un noeud est visité après le parcours infixe de son _SAG_ et avant celui de son _SAD_.
#
#
# > - Affichez le parcours infixe de notre arbre

# %% [markdown]
# > - En utilisant la définition récursive, implémentez la fonction `infixe`.

# %%
# à completer

# %%
# Vérification
print(infixe(arb))

# %% [markdown]
# ---
# ### 💻 EXERCICE 7 - Parcours postfixe d'un arbre binaire
#
# Dans un parcours postfixe, un noeud est visité après le parcours postfixe de son _SAG_ et celui de son _SAD_.
#
#
# > - Affichez le parcours postfixe de notre arbre

# %% [markdown]
# > - En utilisant la définition récursive, implémentez la fonction `postfixe`.

# %%
# à completer

# %%
# Vérification
print(postfixe(arb))

# %% [markdown]
# ---
# ### 💻 EXERCICE 8 - Recherche d'une valeur dans un arbre binaire
#
# On renverra `True` ou `False` en fonction de la présence ou non de la valeur dans une étiquette de l'arbre.
#
# $$recherche(arbre,valeur) = \left\{ \begin {array} {ll} {~si~arbre~est~vide}~~renvoyer~False \\ {~si~arbre.data=valeur}~~renvoyer~True \\{sinon}~~renvoyer~recherche(SAD,valeur)~~ou~recherche(SAD,valeur) \end{array}\right.$$
#
#
# > - Implémentez ci-dessous la fonction `recherche(a, v)`

# %%
# à completer

# %%
# Vérification
print(recherche(arb,5))    # Doit renvoyer True
print(recherche(arb,0))    # Doit renvoyer False

# %% [markdown]
# ---
# ### 💻 EXERCICE 9 - Parcours en largeur d'un arbre binaire
#
# Le parcours en largeur (**BFS**) est le plus simple à faire visuellement, mais il est beaucoup plus difficile à implémenter que les autres parcours.
#
# Il est nécessaire d'utiliser une **file** :
# - On place l'arbre dans la file.
# - Tant que la file n'est pas vide, on procède comme suit :
#     - On défile, donc on récupère l'arbre situé en haut de la file.
#     - Si cet arbre n'est pas vide :
#         - On garde son étiquette.
#         - On enfile son sous-arbre gauche, puis son sous-arbre droit.
#
# 💡 Python propose un module pour utiliser les files, pour cela il suffit d'importer la classe `Queue` du module `queue` :
# ``` Python
# from queue import Queue
# ```
# Ensuite, la méthode `put(e)` sera disponible pour enfiler un élément `e`, la méthode `get()` pour défiler le premier élément de la file et la méthode `empty()` sera disponible pour savoir si la file est vide.
#
#
# > - Affichez le parcours en largeur de notre arbre

# %% [markdown]
# > - En utilisant la définition ci-dessus, implémentez la fonction `bfs`.

# %%
# à completer

# %%
# Vérification
print(bfs(arb))
