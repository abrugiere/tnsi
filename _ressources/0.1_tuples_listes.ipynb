# %% [markdown]
# # Types construits : P-uplets et tableau indexés

# %% [markdown]
# ---
# En classe de première, nous avons vu les différents types simples permettant de stocker de l’information : **int**, **float**, **bool**.
#
# Avec ces types simples, nous pouvons définir des variables qui représenteront chacune **une** donnée avec **une** valeur. Ceci est suffisant pour traiter un petit nombre de données, mais lorsque nous allons vouloir traiter un plus gros volume de données, ceci peut devenir contraignant complexe à gérer.
# Par exemple, si nous voulons gérer un ensemble de points en géométrie, chacun comporte une abscisse et une ordonnée, il nous faudra donc deux valeurs par objet, si nous gérons un train, il sera composé d’une locomotive et d’un ou plusieurs wagons (dont nous ne connaissons pas le nombre à l’avance).
#
# Pour répondre à ce type de besoins, nous allons donc revoir trois nouveaux types d’objets : le type **tuple** (n-uplet), le type **list** (tableau indexé) et le type **dict** (dictionnaire).
#
# Ces types présentent des **points communs** mais aussi des **différences**, ils nous permettront d’adresser des besoins similaires et leur différences nous aideront à faire notre choix en fonction du problème à résoudre.

# %% [markdown]
# ---
# # p-uplets et p-uplets nommés (tuples)
#
# ## Définition
#
# >📌 <font color="#FF0000">Un objet de type **tuple** est une suite ordonnée d’éléments qui peuvent être chacun de n’importe quel type. C’est une séquence d’éléments non modifiables.</font>
#
#
# ## Création
#
# Pour créer un tuple, on utilise les parenthèses et on sépare les éléments par des virgules :

# %%
t = (3,7)

# %%
t

# %%
type(t)

# %% [markdown]
# Un tuple peut être vide

# %%
t=()

# %%
t

# %% [markdown]
# Ou contenir une seule valeur

# %%
t=(4,)

# %%
t

# %%
type(t)

# %% [markdown]
# Attention à ne pas oublier la virgule, sinon le type sera différent

# %%
t=(4)

# %%
t

# %%
type(t)

# %% [markdown]
# Il peut également contenir des objets de types différents

# %%
t = (2,3,'a',8,)

# %%
t

# %% [markdown]
# Un tuple peut contenir un autre tuple

# %%
t = (2,3,'a',(6,7))

# %%
t

# %% [markdown]
# La fonction ```tuple``` permet à partir d’une chaîne de caractères ou d’une liste (que nous verrons plus tard) de créer un tuple :

# %%
t = tuple('Première NSI')

# %%
t

# %% [markdown]
# ## Opérations
# - Concaténation

# %%
t1 = (2,5)
t2 = (7,8)
t3 = t1 + t2

# %%
t3

# %%
t1 = t1 + (2,3)

# %%
t1

# %% [markdown]
# - Multiplication

# %%
t1 = (1,2)
t2 = 3*t1

# %%
t2

# %% [markdown]
# ## Accès aux éléments
#
# Pour accéder aux éléments d’un tuple, on utilise les crochets :

# %%
t = (2,5,6,3,0,3,6)

# %%
t[2]

# %% [markdown]
# Comme pour les chaines de caractères, les indices des éléments commencent à 0 et se terminent à n-1 si n est le nombre d’éléments du tuple.
#
# On accèdera à la longueur d’un tuple avec la fonction ```len```

# %%
len(t)

# %% [markdown]
# Un indice **négatif** permet de parcourir le tuple en partant de la fin (en commençant à -1)

# %%
t[-2]

# %% [markdown]
# On peut accéder à un **tranche** de tuple en utilisant la syntaxe suivante :

# %%
t[2:5]

# %%
t[:5]

# %%
t[3:]

# %%
t[:3] + (10,) + t[4:]

# %% [markdown]
# Pour un tuple contenant un autre tuple, il faudra doubler les indices :

# %%
t = ( ('a','b') , ('c','d') )

# %%
t

# %%
t[0]

# %%
t[1][0]

# %% [markdown]
# >📌 <font color="#FF0000">Pour parcourir les éléments, on peut utiliser une boucle `for`, on dit que les tuples sont **itérables**</font>

# %%
t = (3,5,12)
for elt in t:
    print (elt, end=' ')

# %% [markdown]
# Le tuple peut être également parcouru par ses indices :

# %%
for i in range(len(t)):
    print (t[i], end=' ')

# %% [markdown]
# Pour tester l’appartenance d’un élément à un tuple, on utilise l’opérateur ```in``` :

# %%
t = ('a','b','c')

# %%
'a' in t

# %%
'd' in t

# %% [markdown]
# >📌 <font color="#FF0000">On ne peut pas modifier les éléments d’un tuple par affectation, on dit que les tuples sont **non mutables**</font>

# %%
t[2] = 3

# %% [markdown]
# ## Affectations multiples
#
# La commande ```a,b = 1,2``` affecte 1 à la variable ```a``` et 2 à la variable ```b```. Ceci est en fait lié au fait que Python va affecter au tuple ```(a,b)``` la valeur du tuple ```(1,2)```.
# Cette propriété est très utile pour permuter les valeurs de deux variables sans passer par une variable intermédiaire avec la commande ```a,b = b,a```

# %%
a,b = 1,2

a,b = b,a

# %%
a

# %%
b

# %% [markdown]
# ---
# # Tableau indexé, tableau donné en compréhension
#
# ## Définition
#
# >📌 <font color="#FF0000">Un __tableau__ (type `list` en Python) est une suite ordonnée d’éléments qui peuvent être chacun de n’importe quel type. C’est une séquence d’éléments modifiables.</font>
#
#
#
# ## Création
#
# Pour créer un tableau, on utilise les crochets et on sépare les éléments par des virgules :

# %%
l = [3,7]

# %%
l

# %%
type(l)

# %% [markdown]
# Un tableau peut être vide

# %%
l = []

# %%
l

# %% [markdown]
# Ou contenir une seule valeur

# %%
l = [4,]

# %%
l

# %%
type(l)

# %% [markdown]
# >Vous noterez ici que - contrairement aux tuples - l'oubli de la virgule ne changera pas le type

# %%
l = [4]

# %%
l

# %%
type(l)

# %% [markdown]
# Il peut également contenir des objets de types différents

# %%
l = [2,3,'a',8,]

# %%
l

# %% [markdown]
# Un tableau peut contenir un autre tableau

# %%
l = [2,3,'a',[6,7]]

# %%
l

# %% [markdown]
# La fonction ```list``` permet à partir d’un tuple ou d'une chaîne de caractères, de créer un tableau :

# %%
l = list('Première NSI')

# %%
l

# %%
l = list((1,3,4))

# %%
l

# %% [markdown]
# ## Opérations
# - Concaténation

# %%
l1 = [2,5]
l2 = [7,8]
l3 = l1 + l2

# %%
l3

# %%
l1 = [2,5]
l1 = l1 + [2,3]

# %%
l1

# %% [markdown]
# >Pour concaténer des tableaux, on peut également utiliser la méthode `extend` :

# %%
l1 = [2,5]
l2 = [7,8]
l1.extend(l2)

# %%
l1

# %% [markdown]
# - Multiplication

# %%
l1 = [1,2]
l2 = 3*l1

# %%
l2

# %% [markdown]
# ## Accès aux éléments
#
# Pour accéder aux éléments d’un tableau, on utilise les crochets :

# %%
l = [2,5,6,3,0,3,6]

# %%
l[2]

# %% [markdown]
# Comme pour les chaines de caractères, les indices des éléments commencent à 0 et se terminent à n-1 si n est le nombre d’éléments du tableau.
#
# On accèdera à la longueur d’un tableau avec la fonction ```len```

# %%
len(l)

# %% [markdown]
# Un indice **négatif** permet de parcourir le tableau en partant de la fin (en commençant à -1)

# %%
l[-2]

# %% [markdown]
# On peut accéder à un **tranche** (ou *slice*) d'un tableau en utilisant la syntaxe suivante :

# %%
l[2:5]

# %%
l[:5]

# %%
l[3:]

# %%
l[:3] + [10] + l[4:]

# %% [markdown]
# Pour un tableau contenant un autre tableau, il faudra doubler les indices :

# %%
l = [ ['a','b'] , ['c','d'] ]

# %%
l

# %%
l[0]

# %%
l[1][0]

# %% [markdown]
# >📌 <font color="#FF0000">Pour parcourir les éléments, on peut utiliser une boucle ```for```, on dit que les tableaux sont **itérables**</font>

# %%
l = [3,5,12]
for elt in l:
    print (elt, end=' ')

# %% [markdown]
# Le tableau peut être également parcouru par ses indices :

# %%
for i in range(len(l)):
    print (l[i], end=' ')

# %% [markdown]
# Pour tester l’appartenance d’un élément à un tableau, on utilise l’opérateur ```in``` :

# %%
l = ['a','b','c']

# %%
'a' in l

# %%
'd' in l

# %% [markdown]
# >📌 <font color="#FF0000">On peut modifier les éléments d’un tableau par affectation, on dit que les tableaux sont **mutables**</font>

# %%
l[2] = 3

# %%
l

# %% [markdown]
# ## Modification des tableaux
# Pour ajouter des éléments, on peut utiliser la méthode ```append``` :

# %%
l1 = [2,5]
l1.append(2)
l1.append(3)

# %%
l1

# %% [markdown]
# Pour supprimer des éléments, on peut utiliser la fonction ```del``` ou méthode ```remove``` :

# %%
l=[4, 1, 2, 6, 7, 15, 7]
del l[0]

# %%
l

# %%
l=[4, 1, 2, 6, 7, 15, 7]
l.remove(15)

# %%
l

# %% [markdown]
# Pour insérer des éléments, on peut utiliser la méthode ```insert``` en lui passant en paramètres la position et l'élément à insérer :

# %%
l=[4, 1, 2, 6, 7, 15, 7]
l.insert(3,99)

# %%
l

# %% [markdown]
# Donc ```l.insert(0,x)``` permet d’ajouter x au début du tableau et ```l.insert(-1,x)``` permet d’ajouter x à la fin du tableau.

# %% [markdown]
# La méthode ```pop``` enlève du tableau l’élément situé à la position indiquée et retourne l’élément supprimé :

# %%
l=[ 3 , 6 , 2 , 7 , 1 , 2 , 5]
l.pop(3)

# %%
l

# %% [markdown]
# La méthode ```index``` retourne la position du premier élément du tableau ayant la valeur passée en paramètre :

# %%
l=[ 3 , 6 , 2 , 7 , 1 , 2 , 5]

# %%
l.index(7)

# %%
l.index(2)

# %% [markdown]
# La méthode ```sort``` trie les éléments du tableau dans le tableau lui-même :

# %%
l=[ 3 , 6 , 2 , 7 , 1 , 2 , 5]

# %%
l.sort()

# %%
l

# %% [markdown]
# La fonction ```sorted``` renvoie les éléments du tableau passé en paramètre dans un nouveau tableau :

# %%
l=[ 3 , 6 , 2 , 7 , 1 , 2 , 5]

# %%
sorted(l)

# %%
l

# %% [markdown]
# La methode ```reverse``` inverse les éléments du tableau :

# %%
l=[ 3 , 6 , 2 , 7 , 1 , 2 , 5]

# %%
l.reverse()

# %%
l

# %% [markdown]
# Copie d'un tableau :

# %%
l1=[2,4,1,6,5,7]
l2=l1
l1.append(3)

# %%
l1

# %%
l2

# %% [markdown]
# > Vous noterez ici que lorsqu'on utilise l'opérateur `=` les tableaux l1 et L2 sont liés
# > Pour créer une copie d'un tableau, il faura utiliser la fonction ```list``` :

# %%
l1=[2,4,1,6,5,7]
l2=list(l1)
l1.append(3)

# %%
l1

# %%
l2

# %% [markdown]
# ## Génération des tableaux

# %%
[0]*5

# %%
list('bonjour')

# %%
list(range(5))

# %% [markdown]
# Python permet également de générer un tableau en appliquant une fonction à un ensemble de
# valeurs.
# Cela permet de créer un tableau en une seule ligne au lieu de passer par une boucle.
# >📌 <font color="#FF0000">Cette méthode est appelée **construction par compréhension**</font>

# %%
l=[x**2 for x in range(10)]

# %%
l

# %% [markdown]
# Revient à écrire en une seule ligne le code suivant :

# %%
l=[]
for x in range(10):
    l.append(x**2)

# %%
l

# %% [markdown]
# Il est même possible de filtrer le tableau obtenu à l’aide d’une condition !
# On peut ainsi par exemple obtenir la liste des entiers inférieurs à 50 qui sont des multiples de 3 mais pas de 4 en une seule commande :

# %%
l=[x for x in range(50) if x%3==0 and x%4!=0]

# %%
l

# %% [markdown]
# ---
# ### 💻 EXERCICE 1 - Nom d'un mois
# > En utilisant un tuple (qui contiendra les noms des mois), réalisez une fonction `nom_mois` qui à un entier `n` compris entre 1 et 12 passé en paramètre renvoie le nom du mois correspondant.

# %%
# à compléter

# %%
# Vérification : doit renvoyer "Février"
nom_mois(2)

# %% [markdown]
# ---
# ### 💻 EXERCICE  2 - Appartenance à un tuple
# >Lorsque `t` est un tuple, l’expression `x in t` permet de tester l’appartenance de la valeur de `x` à ce tuple. La réponse est booléenne.

# %%
# à exécuter
1 in (2,8,9,3,1,7,8)

# %%
# à exécuter
0 in (2,8,9,3,1,7,8)

# %% [markdown]
# >Mais on peut avoir besoin de plus d'informations comme l'indice de la valeur ou son nombre d'occurences dans le tuple.
# >- Réalisez une fonction nommée `indice` qui renvoie l’indice de la première occurrence de son premier paramètre `x` dans le tuple `t` passé en second paramètre, si elle existe.

# %%
# à compléter

# %%
# Vérification : doit renvoyer 2
indice (4, (3, 1, 4, 1, 5, 9, 2))

# %% [markdown]
# >- Réalisez maintenant une fonction nommée `nbre_occurrences` qui renvoie le nombre d’occurrences du premier paramètre `x` dans le tuple `t` passé en second paramètre

# %%
# à compléter

# %%
# Vérification : doit renvoyer 3
nbre_occurrences (1, (3,1,4,1,5,1,9,2))

# %% [markdown]
# ---
# ### 💻 EXERCICE  3 - Insertion d’un élément dans un tuple
# >Réalisez une fonction nommée `insere` qui renvoie un tuple dans lequel l’élément `e` a été placé à l’indice `i` dans le tuple `t` avec `e`, `i` et `t` passés en paramètre.

# %%
# à compléter

# %%
# Vérification : doit renvoyer (1, 4, 3, 1, 5, 9)
insere(3,2,(1,4,1,5,9))

# %% [markdown]
# ---
# ### 💻 EXERCICE  4 - Liste des multiples
# > - Avec une boucle, construisez une liste des multiples de 7 jusqu'à 100.

# %%
# à compléter

# %% [markdown]
# > - Construisez la même liste à l'aide de la construction par compréhension

# %%
# à compléter

# %% [markdown]
# ---
# ### 💻 EXERCICE  5 - Recherche dans une liste
# > Écrivez une fonction nommée `recherche` qui prend en paramètres une liste `l` et une valeur `v` et qui renvoie l'indice de la première valeur dans la liste si l'élément est dans la liste et `None` sinon.

# %%
# à compléter

# %%
# Vérification : doit renvoyer 7
recherche([4,5,7,3,6,4,9,2,6,7],2)

# %% [markdown]
# ---
# ### 💻 EXERCICE  6 - Plus grand élément d'une liste
# >- Écrivez une fonction `plus_grand` qui prend en paramètre une liste d'entiers `l` et qui renvoie le plus grand des éléments de la liste.

# %%
# à compléter

# %%
# Vérification : doit renvoyer 14
plus_grand([1,3,6,5,6,14,2,8,0])

# %% [markdown]
# >- Écrivez maintenant une fonction `ind_plus_grand` qui prend en paramètre une liste d'entiers `l` et qui renvoie l'indice du plus grand des éléments de la liste.

# %%
# à compléter

# %%
# Vérification : doit renvoyer 5
ind_plus_grand([1,3,6,5,6,14,2,8,0])

# %% [markdown]
# ---
# ## Exercice Bonus - Le carré magique
#
# >On considère le tableau suivant:
# >![Hello World](data:image/png;base64,...)

# %% [markdown]
# > - Représentez ce tableau à l'aide d'une liste de liste nommée `tab`

# %%
# à compléter

# %% [markdown]
# >- Écrivez une fonction `sommeL` qui prend en paramètre un tableau `t` et un entier `i` et qui renvoie la somme des éléments de la ligne `i`.

# %%
# à compléter

# %%
# Vérification : doit renvoyer 56
sommeL(tab,0)

# %% [markdown]
# > - Écrivez une fonction ```sommeC``` qui prend en paramètre un tableau `t` et un entier `j` et qui renvoie la somme des éléments de la colonne `j`.

# %%
# à compléter

# %%
# Vérification : doit renvoyer 65
sommeC(tab,0)

# %% [markdown]
# > - Écrivez une fonction ```sommeD``` qui prend en paramètre un tableau `t` et qui renvoie la somme de le première diagonale du tableau. (éléments de position 0,0 puis 1,1 etc...)

# %%
 # à compléter

# %%
# Vérification : doit renvoyer 65
sommeD(tab)

# %% [markdown]
# >📌 Un carré est dit "magique" si la somme de ses lignes, la somme de ses colonnes et la somme de ses diagonales sont égales.
# >- Écrivez une fonction `est_magique` qui renvoie `True` si un carré (représenté par un tableau `t` passé en paramètre) est magique et `False` sinon.

# %%
# à compléter

# %%
# Vérification : doit renvoyer True
est_magique(tab)

# %% [markdown]
# >- Le carré suivant est-il magique ?
#
# ![Hello World](data:image/png;base64,...)

# %%
# à compléter
